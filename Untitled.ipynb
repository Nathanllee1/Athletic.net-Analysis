# %%
with open("data/data.txt", "r") as scrapedData:
    data = scrapedData.read()
print(data)

# %%
import pandas as pd

# %%
"[" + data + "]"
# Out:
# '[{\'date\': \'2013-Apr-22\', \'meet\': \'Comstock Park MS VS Allendale MS\', \'event\': \'100 Meters\', \'result\': \'16.24c\', \'gradeLevel\': \'8th Grade\', \'state\': \'MI\'}, {\'date\': \'2013-Apr-24\', \'meet\': \'Comstock Park @ Sparta\', \'event\': \'100 Meters\', \'result\': \'16.00PR\', \'gradeLevel\': \'8th Grade\', \'state\': \'MI\'}, {\'date\': \'2013-May-1\', \'meet\': \'Belding MS Vs Comstock Park MS\', \'event\': \'100 Meters\', \'result\': \'unknown\', \'gradeLevel\': \'8th Grade\', \'state\': \'MI\'}, {\'date\': \'2013-Apr-22\', \'meet\': \'Comstock Park MS VS Allendale MS\', \'event\': \'200 Meters\', \'result\': \'34.44c\', \'gradeLevel\': \'8th Grade\', \'state\': \'MI\'}, {\'date\': \'2013-Apr-24\', \'meet\': \'Comstock Park @ Sparta\', \'event\': \'200 Meters\', \'result\': \'34.60\', \'gradeLevel\': \'8th Grade\', \'state\': \'MI\'}, {\'date\': \'2013-May-1\', \'meet\': \'Belding MS Vs Comstock Park MS\', \'event\': \'200 Meters\', \'result\': \'33.93\', \'gra
# ...

# %%
for resultObject in data:
    print(resultObject)
    df = pd.DataFrame.from_dict(resultObject)
    df
# Out:
# {
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e01b1d92b2b3> in <module>
#       1 for resultObject in data:
#       2     print(resultObject)
# ----> 3     df = pd.DataFrame.from_dict(resultObject)
#       4     df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1136             raise ValueError('only recognize index or columns for orient')
#    1137
# -> 1138         return cls(data, index=index, columns=columns, dtype=dtype)
#    1139
#    1140     def to_numpy(self, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# ...

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
