# %%
with open("data/data5.txt", "r") as scrapedData:
    data = scrapedData.read()
orderedData = "[" + str(data) + "]"

# %%
import pandas as pd

# %%
"[" + str(data) + "]"
# Out:
# '[{\'date\': \'1201-Dec-26\', \'meet\': \'Merli Invitational\', \'event\': \'400 Meters\', \'result\': \'1:13.17PR\', \'gradeLevel\': \'?\', \'state\': \'NJ\'}, {\'date\': \'2015-May-8\', \'meet\': \'Bulldog Frosh/ Soph #4\', \'event\': \'200 Meters\', \'result\': \'32.80PR\', \'gradeLevel\': \'9th Grade\', \'state\': \'NJ\'}, {\'date\': \'2015-May-1\', \'meet\': \'Bulldog Frosh/Soph #3\', \'event\': \'800 Meters\', \'result\': \'3:05.37PR\', \'gradeLevel\': \'9th Grade\', \'state\': \'NJ\'}, {\'date\': \'2015-May-8\', \'meet\': \'Bulldog Frosh/ Soph #4\', \'event\': \'Javelin - 600g\', \'result\': "39\' 1PR", \'gradeLevel\': \'9th Grade\', \'state\': \'NJ\'}, {\'date\': \'2010-May-1\', \'meet\': \'Lakeview Invitational\', \'event\': \'Shot Put - 12lb\', \'result\': "39\' 7.5PR", \'gradeLevel\': \'12th Grade\', \'state\': \'OH\'}, {\'date\': \'2019-Feb-14\', \'meet\': \'Daryl McCulley Quad\', \'event\': \'3200 Meters\', \'result\': \'11:37.80PR\', \'gradeLevel\': \'11th Grade\', \'st
# ...

# %%
print(orderedData)
for results in orderedData:
    print(results)
df = pd.DataFrame.from_dict(orderedData)
# Out:
# [{'date': '1201-Dec-26', 'meet': 'Merli Invitational', 'event': '400 Meters', 'result': '1:13.17PR', 'gradeLevel': '?', 'state': 'NJ'}, {'date': '2015-May-8', 'meet': 'Bulldog Frosh/ Soph #4', 'event': '200 Meters', 'result': '32.80PR', 'gradeLevel': '9th Grade', 'state': 'NJ'}, {'date': '2015-May-1', 'meet': 'Bulldog Frosh/Soph #3', 'event': '800 Meters', 'result': '3:05.37PR', 'gradeLevel': '9th Grade', 'state': 'NJ'}, {'date': '2015-May-8', 'meet': 'Bulldog Frosh/ Soph #4', 'event': 'Javelin - 600g', 'result': "39' 1PR", 'gradeLevel': '9th Grade', 'state': 'NJ'}, {'date': '2010-May-1', 'meet': 'Lakeview Invitational', 'event': 'Shot Put - 12lb', 'result': "39' 7.5PR", 'gradeLevel': '12th Grade', 'state': 'OH'}, {'date': '2019-Feb-14', 'meet': 'Daryl McCulley Quad', 'event': '3200 Meters', 'result': '11:37.80PR', 'gradeLevel': '11th Grade', 'state': 'GA'}, {'date': '2018-Mar-8', 'meet': 'Woodlawn Panther Relays', 'event': '800 Meters', 'result': '3:57.55SR', 'gradeLevel': '10th Gra
# ...

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
